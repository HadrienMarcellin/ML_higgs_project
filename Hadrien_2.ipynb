# %%
import numpy as np
import math
import csv
from proj1_helpers import *
from Hadrien import *
from ML_methods import *
from features_engineering import *
import matplotlib.pyplot as plt


# %load_ext autoreload
# %autoreload 2

y, tx, ids = load_csv_data("data_csv/train.csv", sub_sample=True)

print("y has shape {0}".format(y.shape))
print("X has shape {0}".format(tx.shape))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# y has shape (5000,)
# X has shape (5000, 30)

# %%
id_ = 5
x = tx_nan.copy()
bool_vect = np.zeros(len(x[:, id_]))
print(bool_vect.shape)
print(x.shape)
bool_vect[np.isnan(x[:, id_ ])] = 1
np.hstack( (x, bool_vect.reshape(len(bool_vect), 1)) )
# Out:
# (5000,)
# (5000, 30)
# array([[138.47 ,  51.655,  97.827, ...,  -2.475, 113.497,   0.   ],
#        [219.057,  72.461, 124.835, ...,     nan,  50.396,   1.   ],
#        [ 90.801,  27.787,  65.373, ...,     nan,  62.766,   1.   ],
#        ...,
#        [142.347,   7.389,  99.212, ...,     nan,  97.068,   1.   ],
#        [ 78.162,  46.335,  60.136, ...,     nan,  32.44 ,   1.   ],
#        [130.042,   4.073,  67.819, ...,     nan,  51.037,   1.   ]])

# %%
# Out:
# 5000

# %%
tx_nan = transform_to_nan(tx, -900)

# %%
tx_nan_mean, mean = transform_to_mean(tx_nan)

# %%
tx_nan_mean.shape
# Out:
# (5000, 30)

# %%
from train_model import *

initial_w = np.zeros(tx_nan_mean.shape[1])
max_iter = 1000   
batch_size = 100
gradient_descent_exploration(y, tx_nan_mean, 0.8, np.logspace(-10, -5, 30), initial_w, max_iter)
stochastic_gradient_descent_exploration(y, tx_nan_mean, 0.8, np.logspace(-10, -5, 30), initial_w, batch_size, max_iter)
ridge_regression_exploration(y, tx_nan_mean, 0.8, np.logspace(-10, 10, 30))
# Out:
# Gradient Descent, Loss : 0.351, Lambda : 6.723357536499335e-06
# /home/hadrien/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:70: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims)
# /home/hadrien/ML/local/projects/project1/ML_methods.py:194: RuntimeWarning: overflow encountered in square
#   return 0.5*np.mean(e**2)
# Stochastic Gradient Descent, Loss : 0.359, Lambda : 2.0433597178569437e-06
# Ridge Resgression, Loss : 0.328, Lambda : 1e-10
