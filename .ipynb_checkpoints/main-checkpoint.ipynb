# %%
import numpy as np
import math
import csv
from proj1_helpers import *
from Hadrien import *
from ML_methods import *
import matplotlib.pyplot as plt


# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
y, tx, ids = load_csv_data("data_csv/train.csv", sub_sample=True)

# %%
print("y has shape {0}".format(y.shape))
print("X has shape {0}".format(tx.shape))
# Out:
# y has shape (5000,)
# X has shape (5000, 30)

# %% [markdown]
# ### Feature Normalization

# %%
## TODO : remove NAN before standardization, or at least not consider them in np.mean() and np.std.
tx_nan = transform_to_nan(tx, -900)
tx_nan_norm, mean_x, std_x = standardize_with_nan(tx_nan)

# %% [markdown]
# ### Feature Distribution

# %%
display_feature_distribution(y, tx_nan_norm, 30)

# %% [markdown]
# #### Missing Data

# %%
NAN_values_overview(tx_nan_norm, 20)

# %% [markdown]
# ### Clean Dataset

# %% [markdown]
# With a first glance at the data set we see that some features are almost entirely filled with missing data. Lets say the we remove features and samples with more thant 30% of missing values

# %%
tx_nan_norm.shape
# Out:
# (5000, 30)

# %%
tx_cleaned = tx_nan_norm[:, ~np.isnan(tx_nan_norm).any(axis=0)]
tx_cleaned.shape
# Out:
# (5000, 19)

# %% [markdown]
# ### Train model

# %% [markdown]
# #### Least Square Gradient Descent
# Linear regression using gradient descent

# %%
#initialise le w initial à 30 dim à 0
initial_w = np.zeros(19)
max_iters = 50
gamma = 0.17
losses, ws = gradient_descent(y, tx_cleaned, initial_w, max_iters, gamma)
# Out:
# Gradient Descent(0/49): loss=1.0, w0=-0.05697449971294836, w1=-0.004331103225906298
# Gradient Descent(1/49): loss=0.9291499835521773, w0=-0.09264445217962136, w1=-0.00562096978264681
# Gradient Descent(2/49): loss=0.9039928582979395, w0=-0.11870766844724204, w1=-0.0066650930605821005
# Gradient Descent(3/49): loss=0.8869006090143534, w0=-0.13830717943682072, w1=-0.008055667873582828
# Gradient Descent(4/49): loss=0.8745569669837335, w0=-0.15337963442339353, w1=-0.009994357062526398
# Gradient Descent(5/49): loss=0.8654132825247539, w0=-0.1652188844961846, w1=-0.012506048011125322
# Gradient Descent(6/49): loss=0.8584629189577685, w0=-0.174704945063605, w1=-0.015533472707628188
# Gradient Descent(7/49): loss=0.8530444537561771, w0=-0.18244595437841912, w1=-0.018987868106448546
# Gradient Descent(8/49): loss=0.8487549470217974, w0=-0.18886920592954554, w1=-0.022775169998193602
# Gradient Descent(9/49): loss=0.8452752590092708, w0=-0.19428008633024385, w1=-0.026808466976948157
# Gradient Descent(10/49): loss=0.8424104662553694, w0=-0.19890060485347744, w1=-0.0310129552701242
# Gradient Descent(11/49): loss=0.839995663216327, w0=-0.20289485993809953, w1=-0.035326985482374326
# Gradient Descent(12/49): loss=0.8379257286369202, w0=-0.20638608055648006, w1=-0.03970122672578251
# Gradient Descent(13/49): loss=0.8361327073871037, w0=-0.20946818532492528, w1=-0.04409705807100513
# Gradient Descent(14/49): loss=0.8345611138422196, w0=-0.21221373773588018, w1=-0.04848476942285727
# Gradient Descent(15/49): loss=0.8331655409469128, w0=-0.21467950485596624, w1=-0.052841855482839394
# Gradient Descent(16/49): loss=0.8319111859182104, w0=-0.21691040191380423, w1=-0.057151522328381645
# Gradient Descent(17/49): loss=0.8307724911694772, w0=-0.2189423346635582, w1=-0.061401439563276934
# Gradient Descent(18/49): loss=0.8297312573147341, w0=-0.2208042780467804, w1=-0.06558272836980558
# Gradient Descent(19/49): loss=0.8287694949721145, w0=-0.22251981773346768, w1=-0.06968915742176895
# Gradient Descent(20/49): loss=0.8278755307414476, w0=-0.2241083082000782, w1=-0.07371651310650801
# Gradient Descent(21/49): loss=0.8270410102623973, w0=-0.2255857530147272, w1=-0.07766211138310487
# Gradient Descent(22/49): loss=0.8262587420756426, w0=-0.22696548106097317, w1=-0.08152442229207228
# Gradient Descent(23/49): loss=0.8255210429419138, w0=-0.2282586709073794, w1=-0.08530278272067054
# Gradient Descent(24/49): loss=0.8248266080271515, w0=-0.2294747608285285, w1=-0.0889971775613383
# Gradient Descent(25/49): loss=0.8241666350859225, w0=-0.230621771799418, w1=-0.09260807345089132
# Gradient Descent(26/49): loss=0.8235371927312426, w0=-0.23170656362859604, w1=-0.0961362927003426
# Gradient Descent(27/49): loss=0.8229354306131405, w0=-0.23273503929348852, w1=-0.09958291781748964
# Gradient Descent(28/49): loss=0.8223631718179173, w0=-0.23371230885316474, w1=-0.10294921924975675
# Gradient Descent(29/49): loss=0.8218129152360394, w0=-0.23464282161206643, w1=-0.10623660071911367
# Gradient Descent(30/49): loss=0.8212934542796454, w0=-0.23553047320470516, w1=-0.10944655787183302
# Gradient Descent(31/49): loss=0.8208013547974137, w0=-0.23637869276890866, w1=-0.11258064700287275
# Gradient Descent(32/49): loss=0.8203261289581258, w0=-0.2371905142372374, w1=-0.11564046140549127
# Gradient Descent(33/49): loss=0.8198671353678945, w0=-0.23796863490665957, w1=-0.1186276134968449
# Gradient Descent(34/49): loss=0.8194287588533181, w0=-0.23871546377701203, w1=-0.12154372132414835
# Gradient Descent(35/49): loss=0.8190052413817864, w0=-0.23943316162973388, w1=-0.12439039839832257
# Gradient Descent(36/49): loss=0.8185956469059359, w0=-0.24012367441366558, w1=-0.127169246059888
# Gradient Descent(37/49): loss=0.8181987546110263, w0=-0.24078876118757056, w1=-0.1298818477758794
# Gradient Descent(38/49): loss=0.8178171547189753, w0=-0.24143001761942529, w1=-0.13252976491252347
# Gradient Descent(39/49): loss=0.8174499957433398, w0=-0.24204889584529546, w1=-0.13511453363826875
# Gradient Descent(40/49): loss=0.8170930722889027, w0=-0.2426467213342429, w1=-0.1376376626944948
# Gradient Descent(41/49): loss=0.8167460102081555, w0=-0.24322470728133871, w1=-0.1401006318336218
# Gradient Descent(42/49): loss=0.8164102609839755, w0=-0.24378396695166138, w1=-0.14250489077147638
# Gradient Descent(43/49): loss=0.8160842205337767, w0=-0.2443255243188268, w1=-0.14485185853644622
# Gradient Descent(44/49): loss=0.8157677127280418, w0=-0.2448503232779922, w1=-0.14714292312502977
# Gradient Descent(45/49): loss=0.8154593926042486, w0=-0.2453592356621536, w1=-0.14937944139398213
# Gradient Descent(46/49): loss=0.8151589278592736, w0=-0.24585306824936803, w1=-0.15156273913497784
# Gradient Descent(47/49): loss=0.8148660356219664, w0=-0.2463325689152677, w1=-0.15369411128974517
# Gradient Descent(48/49): loss=0.8145817035099902, w0=-0.2467984320583024, w1=-0.15577482227287195
# Gradient Descent(49/49): loss=0.8143127473228642, w0=-0.24725130340329052, w1=-0.1578061063766133

# %% [markdown]
# #### Least Square Stochastic Gradient Descent
# Linear regression using stochastic gradient descent

# %% [markdown]
# #### Least Square
# Least squares regression using normal equations

# %% [markdown]
# #### Ridge Regression
# Ridge regression using normal equations

# %% [markdown]
# #### Logistic Regression
# Logistic regression using gradient descent or SGD

# %% [markdown]
# #### Reg Logistic Regression
# Regularized logistic regression using gradient descent
# or SGD
